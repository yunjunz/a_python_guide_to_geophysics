# %%
## Estimate Linear Velocity from 3D time-series displacement on Fernandina Volcano

import os
from datetime import datetime as dt
import h5py
import numpy as np
import matplotlib.pyplot as plt

work_dir = os.path.expanduser('~/development/python/a_python_guide_to_geophysics/FernandinaSenDT128')
os.chdir(work_dir)
print('Go to directory:', work_dir)
# Out:
# Go to directory: /Users/yunjunz/development/python/a_python_guide_to_geophysics/FernandinaSenDT128

# %%
# read timeseries HDF5 file
ts_file = 'timeseries.h5'
f = h5py.File(ts_file, 'r')
ts_data = f['timeseries'][:]
date_list = [i.decode('utf8') for i in f['date'][:].tolist()]
f.close()

# %%
## prepare design matrix
dates = [dt.strptime(i, '%Y%m%d') for i in date_list]
years = np.array([i.year + (i.timetuple().tm_yday - 1)/365.25 for i in dates])
A = np.ones((len(years), 2), dtype=np.float32)
A[:, 0] = years
A_inv = np.dot(np.linalg.inv(np.dot(A.T, A)), A.T)

# %%
num_date, length, width = ts_data.shape
vel = np.dot(A_inv, ts_data.reshape(num_date, -1))[0, :].reshape(length, width)
plt.figure()
plt.imshow(vel)
plt.show()

# %%
ts_diff = np.array(ts_data)
for i in range(ts_diff.shape[0]):
    ts_diff[i, :, :] -= ts_data[0, :, :]
B = (np.array(years) - years[0]).reshape(-1, 1)
B_inv = np.dot(np.linalg.inv(np.dot(B.T, B)), B.T)
vel_B = np.dot(B_inv, ts_diff.reshape(num_date, -1)).reshape(length, width)
plt.figure()
plt.imshow(vel_B)
plt.show()

# %%
years_diff
# Out:
# array([0.        , 0.03285421, 0.23066393, 0.26351814, 0.29637235,
#        0.32922656, 0.36208077, 0.39493498, 0.42778919, 0.46064339,
#        0.4934976 , 0.52635181, 0.59206023, 0.62491444, 0.69062286,
#        0.72347707, 0.75633128, 0.78918549, 0.8220397 , 0.85489391,
#        0.88774812, 0.92060233, 0.95345654, 0.98631075, 1.01916496,
#        1.05270363, 1.08555784, 1.11841205, 1.15126626, 1.18412047,
#        1.21697467, 1.3155373 , 1.34839151, 1.38124572, 1.41409993,
#        1.44695414, 1.47980835, 1.54551677, 1.57837098, 1.61122519,
#        1.6440794 , 1.67693361, 1.70978782, 1.74264203, 1.77549624,
#        1.80835044, 1.84120465, 1.87405886, 1.90691307, 1.93976728,
#        1.97262149, 2.0054757 , 2.03832991, 2.06913073, 2.10198494,
#        2.13483915, 2.16769336, 2.20054757, 2.23340178, 2.26625599,
#        2.2991102 , 2.33196441, 2.36481862, 2.39767283, 2.43052704,
#        2.46338125, 2.49623546, 2.52908966, 2.56194387, 2.59479808,
# ...

# %%
y, x = 235, 140
pts_ts = ts_data[:, y, x]
pts_ts -= pts_ts[0]
pts_vel = vel_B[y, x]

off = np.dot(A_inv, ts_data.reshape(num_date, -1))[1, :].reshape(length, width)
pts_ts_lin = (years - years[0]) * pts_vel
#+ off[y, x] / years[0]
#pts_ts_lin = years * pts_vel - years[0]*

plt.figure()
plt.plot(dates, pts_ts, '.')
plt.plot(dates, pts_ts_lin, '--')
plt.show()
